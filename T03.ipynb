# %% [markdown]
# <a href="https://colab.research.google.com/github/navap3206-debug/hello-world/blob/main/T03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio de regresión

# %% [markdown]
# ## Significancia de factores

# %% [markdown]
# |                |   |
# :----------------|---|
# | **Nombre**     | Carlos Santiago Nava Pulido  |
# | **Fecha**      | 10/01/2026  |
# | **Expediente** | 756213  |

# %% [markdown]
# Descarga el archivo de publicidad y carga los datos (Advertising.csv).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from sklearn.linear_model import LinearRegression

# %%
#Analizamos el dataframe
files = files.upload()
data = pd.read_csv('Advertising.csv')
data.head(5)
# Out:
#      <input type="file" id="files-1a3a2d12-5640-41f8-8b95-afd2d19ea93d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a3a2d12-5640-41f8-8b95-afd2d19ea93d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Creamos las matrices y reacomodamos
matrix = (data[['TV', "radio", 'newspaper', 'sales']]).to_numpy()
matrix_x = (matrix[:, 0:3]).reshape(-1,3)
vec_y = (matrix[:, 3]).reshape(-1,1)

# %%
matrix_x
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2],
#        [ 66.1,   5.8,  24.2],
#        [214.7,  24. ,   4. ],
#        [ 23.8,  35.1,  65.9],
#        [ 97.5,   7.6,   7.2],
#        [204.1,  32.9,  46. ],
#        [195.4,  47.7,  52.9],
#        [ 67.8,  36.6, 114. ],
#        [281.4,  39.6,  55.8],
#        [ 69.2,  20.5,  18.3],
#        [147.3,  23.9,  19.1],
#        [218.4,  27.7,  53.4],
#        [237.4,   5.1,  23.5],
#        [ 13.2,  15.9,  49.6],
#        [228.3,  16.9,  26.2],
#        [ 62.3,  12.6,  18.3],
#        [262.9,   3.5,  19.5],
#        [142.9,  29.3,  12.6],
#        [240.1,  16.7,  22.9],
#        [248.8,  27.1,  22.9],
#        [ 70.6,  16. ,  40.8],
#        [292.9,  28.3,  43.2],
# ...

# %%
vec_y
# Out:
# array([[22.1],
#        [10.4],
#        [ 9.3],
#        [18.5],
#        [12.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [10.6],
#        [ 8.6],
#        [17.4],
#        [ 9.2],
#        [ 9.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [12.5],
#        [ 5.6],
#        [15.5],
#        [ 9.7],
#        [12. ],
#        [15. ],
#        [15.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [ 9.6],
#        [17.4],
#        [ 9.5],
#        [12.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [12.9],
#        [ 8.5],
#        [14.9],
#        [10.6],
#        [23.2],
#        [14.8],
#        [ 9.7],
#        [11.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
# ...

# %% [markdown]
# **¿Hay alguna relación entre el presupuesto para publicidad y las ventas?**
#
# Nuestra primera meta debe ser determinar si hay evidencia en los datos de que haya una asociación entre estas variables.
#
# - ¿Por qué? ¿Qué resultaría si nos diéramos cuenta de la falta de relación entre el presupuesto de publicidad y las ventas?

# %% [markdown]
# Debido a que entrenamos las regresiones mediante muestras, debemos asegurarnos de que el comportamiento de las muestras tenga una relación significativa con la población.  Si nos dieramos cuenta de que existiera  falta de información no podríamos utilizar estos datos para interpolar ni extrapolar en caso de realizar una regresión.

# %% [markdown]
# **¿Qué tan fuerte es esta relación?**
# Asumiendo que existe esta relación, ¿nos sirve conocer el impacto que tiene invertir en publicidad en las ventas?

# %% [markdown]
# Si, porque nos permitiria desarrollar estrategías donde ser mejore la repartición de recursos según el peso que represente o en todo caso evitar invertir y abandonar la estrategia.

# %% [markdown]
# **¿Cuáles medios están asociados con las ventas? ¿Qué tan grande es la asociación entre un medio específico y las ventas?**
#
# Hay 3 medios distintos en los datos. ¿Sirve invertir en los 3? ¿Conviene más invertir sólo en uno?
#
# **¿Qué tan seguros estamos de que podríamos predecir ventas futuras?**
#
# **¿La relación es lineal?**
#
# **¿Hay sinergia entre estos medios?**
#
# Puede ser que gastar \\$50,000 en publicidad y otros \\$50,000 en radio es mejor opción que gastar \\$100,000 en televisión. A esto le llamamos efecto de interacción.
#
# Podemos usar regresión lineal para responder todas estas preguntas.

# %% [markdown]
# Realiza una regresión lineal:
#
# $$ \text{ventas} \approx \beta_0 + (\beta_1)(\text{TV})$$

# %%
matrix_TV = matrix[:, 0].reshape(-1,1)
matrix_TV
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
# ...

# %%
lr_TV = LinearRegression(fit_intercept=True)
lr_TV.fit(matrix_TV, vec_y)
lr_TV.coef_,lr_TV.intercept_
# Out:
# (array([[0.04753664]]), array([7.03259355]))

# %%
lr_TV.score(matrix_TV, vec_y)
# Out:
# 0.611875050850071

# %% [markdown]
# ### Verificando la precisión de nuestros coeficientes estimados

# %% [markdown]
# Recuerda que en el mundo real hay ruidos y errores de medición. Siempre se asume que la verdadera relación entre $X$ y $Y$ es $$Y = \beta_0 + \beta_1 X + \epsilon$$

# %% [markdown]
# Se asume que el término de error es independiente de $X$ (el error siempre es el mismo sin importar el valor de $X$). Este modelo describe a la *línea de regresión de la población*, que es la mejor aproximación de la verdadera relación entre $X$ y $Y$. Cuando usamos mínimos cuadrados encontramos la *línea de mínimos cuadrados*.

# %% [markdown]
# ¿Cuál es la diferencia entre población y muestra?

# %% [markdown]
# Una población posee un comportamiento bien definido con una distribución invariable, una muestra es una agrupación de datos perteneciente a una población los cuales se asume según una distribucíon normal poseen una media similar a la de la población, por eso mismo se pueden inferir comportamientos a partir de muestras.

# %% [markdown]
# ¿Cuál crees que sea la diferencia entre hacer una regresión con todos los datos de la población y una muestra de ella?

# %% [markdown]
# La población entrenaria una regresión en la que es seguro un comportamiento similar a los esperado, en cambio si obtienes una muestra no puedes saber si representa correctamente a la población, aspi que posterior debes asegurarte que la muestra sea significativa y pertenesca a la distribución correcta.

# %% [markdown]
# La línea de regresión de la población no se puede observar. El concepto de comparar estas líneas es una extensión natural del acercamiento estadístico estándar de usar información de una muestra para estimar características de una población grande.

# %% [markdown]
# Imagina que quieres encontrar la altura promedio de un mexicano $\mu$. Medir a todos y cada uno de los mexicanos en situaciones similares, con la misma regla, mismo operador, y otras incontables formas de minimizar la variación de la medida es una tarea imposible. Lo que podemos asumir es que $\hat{\mu} = \bar{y}$. La media poblacional y la media muestral son diferentes, pero la media muestral es usualmente un buen estimado.
#
# De la misma manera, como no contamos con el 100% de la información para hacer una regresión, los coeficientes $\beta_0$ y $\beta_1$ son desconocidos. Podemos estimarlos usando mínimos cuadrados, encontrando $\hat{\beta_0}$ y $\hat{\beta_1}$. Puede que las muestras que tengamos en ese momento estén un poco por encima de la media, pero otras muestras en otro momento puede que estén debajo de la media. En general, esperamos que el promedio de las aproximaciones $\hat{\mu}$ aproxime a $\mu$.

# %% [markdown]
# Esto lleva a la pregunta: ¿qué tan cercanos son nuestros coeficientes estimados a los verdaderos coeficientes? Utilizamos el concepto de error estándar para evaluar esto.
#
# $$ \text{Var}(\hat{\mu})=\text{SE}(\hat{\mu})^2 = \frac{\sigma^2}{n} $$
#
# Donde $\sigma$ es la desviación estándar de cada una de las observaciones $y_i$ de $Y$. El error estándar nos dice la cantidad promedio que el estimado difiere del valor verdadero. Podemos ver en la fórmula que entre más observaciones tengamos el error se hace más pequeño. Las fórmulas para errores estándar de $\hat{\beta_0}$ y $\hat{\beta_1}$ son:
#
# $$ \text{SE}(\hat{\beta_0})^2 = \sigma^2 [\frac{1}{n} + \frac{\bar{x}^2}{\sum_{i=1}^n (x_i - \bar{x})^2}]$$
#
# $$ \text{SE}(\hat{\beta_1})^2 = \frac{\sigma^2}{\sum_{i=1}^n (x_i - \bar{x})^2}$$
#
# $$ \sigma^2 = \text{Var}(\epsilon) = \text{RSE}^2 = \frac{\text{RSS}}{n-p}$$

# %% [markdown]
# Para que estas fórmulas sean validas asumimos que los errores $\epsilon_i$ tienen varianza común $\sigma^2$ y que no están correlacionados.
#
# Calcula los errores estándar de los coeficientes

# %%
#PARA CONSEGUIR LAS VARIANZAS NECESITAMOS RSS
RSS = np.sum((vec_y - lr_TV.predict(matrix_TV))**2)
p = 2 #Hay dos coeficientes
var_TV = RSS/(len(vec_y)-p) #en este caso son dos
var_TV
# Out:
# np.float64(10.618841328946218)

# %%
#SACAMOS STANDARD ERROR DE B0
SE_TV_B_0 = (var_TV)*((1/len(vec_y)) + (((np.mean(matrix_TV)**2) / np.sum((matrix_TV - np.mean(matrix_TV))**2))))
SE_TV_B_0 = SE_TV_B_0**(1/2)
SE_TV_B_0
# Out:
# np.float64(0.4578429402734785)

# %%
#SACAMOS STANDARD ERROR DE B1

SE_TV_B_1 = var_TV/np.sum((matrix_TV- np.mean(matrix_TV))**2)
SE_TV_B_1 = SE_TV_B_1**(1/2)
SE_TV_B_1
# Out:
# np.float64(0.0026906071877968707)

# %% [markdown]
# Estos errores se pueden usar para calcular intervalos de confianza. Un intervalo de confianza del $95\%$ se define como un rango de valores en el cuál se encuentra el desconocido valor verdadero con un $95\%$ de probabilidad.
#
# Otra forma de verlo es que si tomamos muestras repetidas y construimos un intervalo de confianza para cada una, el $95\%$ de los intervalos creados van a contener el valor verdadero. Para la regresión el intervalo de confianza del $95\%$ toma la forma:
#
# $$ \hat{\beta_j} \pm 2\text{SE}(\hat{\beta_j})$$

# %% [markdown]
# Calcula los intervalos de confianza para los coeficientes estimados:

# %%
#INTERVALOS DE CONFIANZA PARA INTERCPTO
lm1_0 = lr_TV.intercept_ + 2*SE_TV_B_0

# %%
lm2_0 = lr_TV.intercept_ - 2*SE_TV_B_0

# %%
#INTERVALOS DE CONFIANZA PARA INTERCPTO
lm1_1 = lr_TV.coef_ + 2*SE_TV_B_1

# %%
lm2_1 = lr_TV.coef_ - 2*SE_TV_B_1

# %% [markdown]
# Los errores estándar también se usan para realizar pruebas de hipótesis. La prueba de hipótesis más común es probar la hipótesis nula de:
#
# $$ H_0: \text{No hay relación entre } X \text{ y } Y \ \ \ \ (\beta_1=0)$$

# %% [markdown]
# contra la hipótesis alternativa:
# $$ H_0: \text{Hay alguna relación entre } X \text{ y } Y \ \ \ (\beta_1 \neq 0)$$

# %% [markdown]
# Explica con tus palabras el significado de la hipótesis nula y la hipótesis alternativa.

# %% [markdown]
# La hipotesis nula es aquella afurmación que significaría que la muestra es parte de otrra distribución, miestras que la hiotesis alternatva confirmaría que los datos debería ser una distribución que imita cofrrectamente el comportamiento de la población.

# %% [markdown]
# Para probal la hipótesis nula debemos determinar si nuestro estimado $\hat{\beta_1}$ de $\beta_1$ está lo suficientemente alejado de cero para que podamos decir con confianza que este valor no es cero.
#
# ¿Qué tan lejos? Depende de qué tanta confianza tengamos en el estimado encontrado. Si nuestro error estándar es pequeño y nuestro estimado está alejado de cero podríamos decir que hay muy poca probabilidad de que el valor verdadero sea 0. En cambio, si nuestro error estándar es grande y nuestro estimado está muy cerca de cero, entonces podrías ser que el valor verdadero sea cero y que no haya relación entre las variables.

# %% [markdown]
# Se calcula un *estadístico t* dado por
# $$ t = \frac{\hat{\beta_j} - \mu}{\text{SE}(\hat{\beta_j})} $$

# %% [markdown]
# donde $\mu$ es el valor contra el que queremos probar.
#
# Calcula el estadístico t para tus coeficientes estimados, usando como referencia la prueba de hipótesis.

# %%
B1 = (lm1_0 ,lm2_1 )
B0 = (lm1_1 ,lm2_1 )

# %%
t0 = (lr_TV.intercept_ - 0)/SE_TV_B_0
t0
# Out:
# array([15.36027517])

# %%
t1 = (lr_TV.coef_ - 0)/SE_TV_B_1
t1
# Out:
# array([[17.6676256]])

# %% [markdown]
# La distribución t tiene forma de campana y se parece bastante a la distribución normal cuando $n > 30$. Ya sólo es cuestión de calcular la probabilidad de observar cualquier número tal que su valor absoluto sea igual o mayor que el valor absoluto del estadístico t calculado. En otras palabras:
# $$ P(|x| \geq |t|) $$

# %% [markdown]
# A esta probabilidad la llamamos *p-value*. Un *p-value* pequeño indica que es poco probable que exista por puro azar una relación significativa entre predictor y respuesta, en caso de que no haya una asociación real entre predictor y respuesta. En otras palabras, el *p-value* te dice la probabilidad de que parezca que hay relación cuando no la hay.
#
# Si el *p-value* es pequeño, inferimos que sí hay una asociación entre el predictor y la respuesta, y **rechazamos la hipótesis nula**.

# %% [markdown]
# ¿Qué tan pequeño? Depende de la aplicación. Un valor muy común es del $5\%$.
#
# Utiliza el siguiente código para calcular el *p-value* para tus coeficientes
#
# `from scipy import stats`
#
# `p_bj = 2*(1 - stats.t.cdf(np.abs(t_bj), n-p))`

# %%
from scipy import stats

# %%
p_b0 = 2*(1-stats.t.cdf(np.abs(t0),len(vec_y)-p))
p_b0
# Out:
# array([0.])

# %%
p_b1 = 2*(1-stats.t.cdf(np.abs(t1),len(vec_y)-p))
p_b1
# Out:
# array([[0.]])

# %% [markdown]
# ¿Se rechaza la hipótesis nula? ¿Qué significa?

# %% [markdown]
# Rechazamos Ho y aprobamos H1 ya que Bj es diferente a 0, la muestra es representa significativamente  la población

# %% [markdown]
# Realiza otras dos regresiones. Ya tienes hecha la regresión de ventas dado el gasto en publicidad de TV. Realiza la regresión para gastos en radio y gastos en periódico. Organiza las respuestas para que debajo de esta celda se tenga:
# - Título de regresión
# - Coeficientes estimados
# - Errores estándar de los coeficientes
# - Intervalos de confianza
# - Estadísticos t
# - p-values
# - Observaciones

# %% [markdown]
# ***RADIO***

# %%
matrix_rd = matrix[:, 1].reshape(-1,1) #Seleccionamos los datos de radio
matrix_rd
# Out:
# array([[37.8],
#        [39.3],
#        [45.9],
#        [41.3],
#        [10.8],
#        [48.9],
#        [32.8],
#        [19.6],
#        [ 2.1],
#        [ 2.6],
#        [ 5.8],
#        [24. ],
#        [35.1],
#        [ 7.6],
#        [32.9],
#        [47.7],
#        [36.6],
#        [39.6],
#        [20.5],
#        [23.9],
#        [27.7],
#        [ 5.1],
#        [15.9],
#        [16.9],
#        [12.6],
#        [ 3.5],
#        [29.3],
#        [16.7],
#        [27.1],
#        [16. ],
#        [28.3],
#        [17.4],
#        [ 1.5],
#        [20. ],
#        [ 1.4],
#        [ 4.1],
#        [43.8],
#        [49.4],
#        [26.7],
#        [37.7],
#        [22.3],
#        [33.4],
#        [27.7],
#        [ 8.4],
#        [25.7],
#        [22.5],
#        [ 9.9],
#        [41.5],
#        [15.8],
#        [11.7],
#        [ 3.1],
#        [ 9.6],
#        [41.7],
#        [46.2],
#        [28.8],
#        [49.4],
#        [28.1],
#        [19.2],
# ...

# %%
lr_rd = LinearRegression(fit_intercept=True) #Rwalizamos la regresión
lr_rd.fit(matrix_TV, vec_y)
lr_rd.coef_,lr_TV.intercept_
# Out:
# (array([[0.20249578]]), array([7.03259355]))

# %%
lr_rd.score(matrix_rd, vec_y)
# Out:
# 0.33203245544529525

# %%
#PARA CONSEGUIR LAS VARIANZAS NECESITAMOS RSS
RSS = np.sum((vec_y - lr_rd.predict(matrix_rd))**2)
p = 2 #Hay dos coeficientes
var_rd = RSS/(len(vec_y)-p) #en este caso son dos
var_rd
# Out:
# np.float64(18.275149237500443)

# %%
#SACAMOS STANDARD ERROR DE B0
SE_rd_B_0 = (var_rd)*((1/len(vec_y)) + (((np.mean(matrix_rd)**2) / np.sum((matrix_rd - np.mean(matrix_rd))**2))))
SE_rd_B_0 = SE_rd_B_0**(1/2)
SE_rd_B_0
# Out:
# np.float64(0.5629004962718711)

# %%
#SACAMOS STANDARD ERROR DE B1
SE_rd_B_1 = var_rd/np.sum((matrix_rd- np.mean(matrix_rd))**2)
SE_rd_B_1 = SE_rd_B_1**(1/2)
SE_rd_B_1
# Out:
# np.float64(0.020411306360090635)

# %%
#INTERVALOS DE CONFIANZA PARA INTERCPTO
lm1_rd_0 = lr_rd.intercept_ + 2*SE_rd_B_0

# %%
lm2_rd_0 = lr_rd.intercept_ - 2*SE_rd_B_0

# %%
#INTERVALOS DE CONFIANZA PARA INTERCPTO
lm1_rd_1 = lr_rd.coef_ + 2*SE_rd_B_1

# %%
lm2_rd_1 = lr_rd.coef_ - 2*SE_rd_B_1

# %%
#INTERVALOS
B1_rd = (lm1_0 ,lm2_1 )
B0_rd = (lm1_1 ,lm2_1 )

# %%
#ESTADISTICO
t0_rd = (lr_rd.intercept_ - 0)/SE_rd_B_0


t0_rd
# Out:
# array([16.54224531])

# %%
t1_rd = (lr_rd.coef_ - 0)/SE_rd_B_1
t1_rd
# Out:
# array([[9.92076547]])

# %%
#PRUEBA DE HIPOTESIS
p_b0_rd = 2*(1-stats.t.cdf(np.abs(t0_rd),len(vec_y)-p))
p_b0
P_b1_rd = 2*(1-stats.t.cdf(np.abs(t1_rd),len(vec_y)-p))
print(p_b0
,P_b1_rd)
# Out:
# [0.] [[0.]]

# %% [markdown]
# ***NEWSPAPER***

# %%
matrix_nw = matrix[:, 2].reshape(-1,1) #Separmaos los datos newspaper
matrix_nw
# Out:
# array([[ 69.2],
#        [ 45.1],
#        [ 69.3],
#        [ 58.5],
#        [ 58.4],
#        [ 75. ],
#        [ 23.5],
#        [ 11.6],
#        [  1. ],
#        [ 21.2],
#        [ 24.2],
#        [  4. ],
#        [ 65.9],
#        [  7.2],
#        [ 46. ],
#        [ 52.9],
#        [114. ],
#        [ 55.8],
#        [ 18.3],
#        [ 19.1],
#        [ 53.4],
#        [ 23.5],
#        [ 49.6],
#        [ 26.2],
#        [ 18.3],
#        [ 19.5],
#        [ 12.6],
#        [ 22.9],
#        [ 22.9],
#        [ 40.8],
#        [ 43.2],
#        [ 38.6],
#        [ 30. ],
#        [  0.3],
#        [  7.4],
#        [  8.5],
#        [  5. ],
#        [ 45.7],
#        [ 35.1],
#        [ 32. ],
#        [ 31.6],
#        [ 38.7],
#        [  1.8],
#        [ 26.4],
#        [ 43.3],
#        [ 31.5],
#        [ 35.7],
#        [ 18.5],
#        [ 49.9],
#        [ 36.8],
#        [ 34.6],
#        [  3.6],
#        [ 39.6],
#        [ 58.7],
#        [ 15.9],
# ...

# %%
lr_nw = LinearRegression(fit_intercept=True)
lr_nw.fit(matrix_nw, vec_y)
lr_nw.coef_,lr_nw.intercept_
# Out:
# (array([[0.0546931]]), array([12.35140707]))

# %%
#PARA CONSEGUIR LAS VARIANZAS NECESITAMOS RSS
RSS = np.sum((vec_y - lr_nw.predict(matrix_nw))**2)
p = 2 #Hay dos coeficientes
var_nw = RSS/(len(vec_y)-p) #en este caso son dos
var_nw
# Out:
# np.float64(25.933356283393632)

# %%
#SACAMOS STANDARD ERROR DE B0
SE_nw_B_0 = (var_nw)*((1/len(vec_y)) + (((np.mean(matrix_nw)**2) / np.sum((matrix_nw - np.mean(matrix_nw))**2))))
SE_nw_B_0 = SE_nw_B_0**(1/2)
SE_nw_B_0
# Out:
# np.float64(0.6214201876094345)

# %%
#SACAMOS STANDARD ERROR DE B1
SE_nw_B_1 = var_nw/np.sum((matrix_nw- np.mean(matrix_nw))**2)
SE_nw_B_1 = SE_nw_B_1**(1/2)
SE_nw_B_1
# Out:
# np.float64(0.016575721876358165)

# %%
#INTERVALOS DE CONFIANZA PARA INTERCPTO
lm1_nw_0 = lr_nw.intercept_ + 2*SE_nw_B_0

# %%
lm2_nw_0 = lr_nw.intercept_ - 2*SE_nw_B_0

# %%
#INTERVALOS DE CONFIANZA PARA INTERCPTO
lm1_nw_1 = lr_nw.coef_ + 2*SE_nw_B_1

# %%
lm2_nw_1 = lr_nw.coef_ - 2*SE_nw_B_1

# %%
#INTERVALOS
B1_nw = (lm1_0 ,lm2_1 )
B0_nw = (lm1_1 ,lm2_1 )

# %%
#ESTADISTICO
t0_nw = (lr_nw.intercept_ - 0)/SE_nw_B_0
t0_nw
# Out:
# array([19.87609562])

# %%
t1_nw = (lr_nw.coef_ - 0)/SE_nw_B_1
t1_nw
# Out:
# array([[3.29959074]])

# %%
#PRUEBA DE HIPOTESIS
p_b0_nw = 2*(1-stats.t.cdf(np.abs(t0_nw),len(vec_y)-p))
p_b0
P_b1_nw = 2*(1-stats.t.cdf(np.abs(t1_nw),len(vec_y)-p))
print(p_b0
,P_b1_rd)
# Out:
# [0.] [[0.]]

# %% [markdown]
# NO POSEEMOS EVIDENCI DE QUE LA MUESTRA NO SEA SIGNIFICATIVA

# %% [markdown]
# ## Regresión lineal múltiple

# %% [markdown]
# En lugar de hacer una regresión para cada factor independiente, quizás se puede extender el modelo para que tenga varios factores dentro:
#
# $$ Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 + ... + \beta_p X_p + \epsilon $$
#
# Para nuestro ejemplo de publicidad:
#
# $$ \text{sales} = \beta_0 + \beta_1 (\text{TV}) + \beta_2 (\text{radio}) + \beta_3 (\text{newspaper}) + \epsilon $$

# %% [markdown]
# Utiliza la librería `statsmodels` para realizar la regresión. Por defecto la librería statsmodels no toma en cuenta el intercepto ($\beta_0$), por lo que se tendrá que agregar una columna de unos de tamaño *n* a la matriz X.
#
# `import statsmodels.api as sm`
#
# `ols = sm.OLS(Y, X)`
#
# `results = ols.fit()`
#
# `results.summary()`

# %%
import statsmodels.api as SM
X2 = SM.add_constant(matrix_x) #CONCADENAR
model = SM.OLS(vec_y,X2) #MODELO MINIMOS CUADRADOS ORDINARIOS
results = model.fit() #OPTIMIZA
print(results.summary())#RESUME
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Mon, 02 Feb 2026   Prob (F-statistic):           1.58e-96
# Time:                        22:41:31   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %% [markdown]
# ¿Qué diferencias puedes observar entre los *p-values* de una regresión múltiple y los encontrados en las regresiones simples? ¿Por qué crees que existen estas diferencias?

# %% [markdown]
# Los p values individuales resultan ser optimos para realizar una regresión de confianza, cunado realizamos el analisis conjunto o multiple newspaper resulta no tener una rlació n significativa como para confiar en la regesión.

# %% [markdown]
# ## Referencia
#
# James, G., Witten, D., Hastie, T., Tibshirani, R.,, Taylor, J. (2023). An Introduction to Statistical Learning with Applications in Python. Cham: Springer. ISBN: 978-3-031-38746-3
